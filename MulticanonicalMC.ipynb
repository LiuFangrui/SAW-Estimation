# %%
#MCMC

import numpy as np
import random
from collections import defaultdict
import matplotlib.pyplot as plt

def generate_initial_saw(L):
    """Initial straight walk (L steps = L+1 points)."""
    return [(i, 0) for i in range(L+1)]

def apply_pivot(walk, pivot_idx):
    """Apply random symmetry operation to the segment after pivot_idx."""
    pivot = walk[pivot_idx]
    segment = walk[pivot_idx+1:]
    
    # Symmetry operations (rigid transformations in 2D)
    operations = [
        lambda p: (2 * pivot[0] - p[0], p[1]),       # X-reflection
        lambda p: (p[0], 2 * pivot[1] - p[1]),       # Y-reflection
        lambda p: (pivot[0] - (p[1] - pivot[1]),     # +90° rotation
                pivot[1] + (p[0] - pivot[0])),
        lambda p: (pivot[0] + (p[1] - pivot[1]),     # -90° rotation
                pivot[1] - (p[0] - pivot[0])),
        lambda p: (2 * pivot[0] - p[0], 2 * pivot[1] - p[1]),  # 180° rotation

    ]
    op = random.choice(operations)
    new_segment = [op(p) for p in segment]
    new_walk = walk[:pivot_idx+1] + new_segment
    
    # Check self-avoidance (exact coordinate comparison)
    # Exact coordinate comparison
    if len(set(new_walk)) == len(new_walk):
        return new_walk
    return None  # Reject if invalid

def MCMC_SAW(L, num_steps, num_chains, reject):
    """Improved MCMC for SAWs with pivot moves."""
    #unique_counts = defaultdict(int)
    accepted_moves  = 0
    
    
    for _ in range(num_chains):
        current = generate_initial_saw(L)
        #unique_counts[tuple(current)] += 1
        #reject is meant to reject the first few moves to allow the chain to equilibrate (not sure if it makes a impact)
        rejected = reject
        
        for __ in range(num_steps):
            pivot_point = random.randint(1, L-1)
            new_walk = apply_pivot(current, pivot_point)
            
            if new_walk is not None and rejected <= 0:
                current = new_walk
                accepted_moves  += 1
                #unique_counts[tuple(current)] += 1
            else:
                rejected -= 1
            #unique_saws.add(tuple(current))
    
    return accepted_moves  / (num_steps * num_chains)


L = 5           # Small L for testing (exact c_L for L=5 is 396 on square lattice)
num_steps = 10000 # Steps per chain
num_chains = 10  # Independent chains

# Estimation
mu_estimates = []
acceptance_rates = []
for L in range(10, 51, 10):
    acceptance_rate = MCMC_SAW(L, num_steps, num_chains, 10)
    acceptance_rates.append(acceptance_rate)
    print(f"Acceptance rate for L={L}: {acceptance_rate:.4f}")

#plot acceptance rates against 1/L
plt.figure(figsize=(8, 5))# Set figure size
plt.plot([1/L for L in range(10, 51, 10)], acceptance_rates, marker='o', linestyle='-', color='b')
plt.xlabel('1/L')  # X-axis label
plt.ylabel('Acceptance Rate')  # Y-axis label
plt.title('Acceptance Rate vs 1/L')  # Title of the plot
plt.grid()  # Show grid
plt.show()  # Display the plot
# Out:
# Acceptance rate for L=10: 0.5850
# Acceptance rate for L=20: 0.5196
# Acceptance rate for L=30: 0.4838
# Acceptance rate for L=40: 0.4592
# Acceptance rate for L=50: 0.4394

# %%
acceptance_rates = []

Lstart = 100
Lend = 2000
num_steps = 10000 # Steps per chain
num_chains = 100  # Independent chains

for L in range(Lstart, Lend, 50):
    acceptance_rate = MCMC_SAW(L, num_steps, num_chains, 100)
    acceptance_rates.append(acceptance_rate)
    print(f"L = {L}, Acceptance Rate = {acceptance_rate:.4f}")

# %%
# Generate x-values (L^(-0.19)) and acceptance rates
x_values = [L**-0.19 for L in range(Lstart, Lend, 50)]
y_values = acceptance_rates
print(x_values)
print(y_values)

m, c = np.polyfit(x_values, y_values, 1)

best_fit_y = [m * x + c for x in x_values]

# Plot data points
plt.figure(figsize=(8, 5))
plt.plot(x_values, y_values, marker='o', linestyle='-', color='b', label='Acceptance Rate')
plt.plot(x_values, best_fit_y, linestyle='--', color='r', label=f'Best Fit Line (Slope = {m:.4f})')

# Labels and grid
plt.xlabel('L^(-0.19)')  
plt.ylabel('Acceptance Rate')  
plt.title('Acceptance Rate vs L^(-0.19)')  
plt.legend()
plt.grid()
plt.show()

# Print estimated 1/mu
print(f"Estimated μ ≈ {1/(m*0.5):.4f}")
# Out:
# [0.4168693834703354, 0.3859603226440396, 0.3654300865915842, 0.3502606895728793, 0.33833502703074797, 0.3285693673732094, 0.3203381046471968, 0.31324894888535215, 0.3070405244316857, 0.301530389701948, 0.2965864204167691, 0.29211002523080454, 0.28802578728854555, 0.28427479823037055, 0.28081021528926753, 0.27759421042018867, 0.2745958207891339, 0.271789400058918, 0.26915348039269155, 0.2666699215621366, 0.26432326476338125, 0.2621002349976261, 0.25998935300198267, 0.25798062913371433, 0.2560653193710946, 0.25423572896190116, 0.2524850530236944, 0.2508072460915188, 0.2491969145547043, 0.24764922734914524, 0.24615984132655944, 0.2447248385120617, 0.2433406730585447, 0.24200412616206532, 0.24071226755322747, 0.23946242245179822, 0.23825214308470025, 0.2370791840352305]
# ...

# %%
# Multicanonical sampling for self-avoiding walks (SAWs) in 2D

import numpy as np
import random
from collections import defaultdict
import matplotlib.pyplot as plt

def Rg(SAW): # Calculate the radius of gyration of a self-avoiding walk (SAW)
    SAW = np.array(SAW)
    center_of_mass = np.mean(SAW, axis=0)
    return np.sqrt(np.mean(np.sum((SAW - center_of_mass) ** 2, axis=1))) 

def get_rg_bin(rg, bins):
    return int(np.digitize(rg, bins))  # bin index

def apply_pivot(walk, pivot_idx):
    pivot = walk[pivot_idx]
    segment = walk[pivot_idx+1:]
    operations = [
        lambda p: (2*pivot[0] - p[0], p[1]),
        lambda p: (p[0], 2*pivot[1] - p[1]),
        lambda p: (pivot[0] - (p[1] - pivot[1]), pivot[1] + (p[0] - pivot[0])),
        lambda p: (pivot[0] + (p[1] - pivot[1]), pivot[1] - (p[0] - pivot[0])),
        lambda p: (2*pivot[0] - p[0], 2*pivot[1] - p[1])
    ]
    op = random.choice(operations)
    new_segment = [op(p) for p in segment]
    new_walk = walk[:pivot_idx+1] + new_segment
    if len(set(new_walk)) == len(new_walk):
        return new_walk
    return None

def is_flat(hist, threshold=0.6, min_count=10000):
    values = np.array(list(hist.values()))
    values = values[4:-4]
    if len(values) == 0:
        return False
    #print("flat", np.min(values),  threshold * np.mean(values),np.max(values), (2-threshold) * np.mean(values))
    return np.min(values) > threshold * np.mean(values) and np.max(values) < (2-threshold) * np.mean(values)

def mse_hist(histogram):
    """Compute MSE of histogram counts, excluding edge bins."""
    values = np.array(list(histogram.values()))
    if len(values) <= 2:  # Not enough bins to exclude edges
        return 0.0
    values = values[4:-4]  # Exclude first and last bins
    mean = np.mean(values)
    mse = np.mean((values - mean) ** 2)
    return mse

def multicanonical_wl(L, n_steps=100_000):
    current_saw = [(i, 0) for i in range(L+1)]
    rg_bins = np.linspace(0.5 * np.sqrt(L), (L / np.sqrt(12)) * 1.05, 50) # estimated min rg and max rg
    log_weights = defaultdict(float)
    visits = defaultdict(int)

    f = np.e  # initial modification factor
    hist = defaultdict(int)
    flat_check_interval = 20_000  # steps between checking flatness
    reset_interval = L*100  # steps between checking flatness
    max_f_iters = 20  # max number of times to reduce f

    f_iters = 0
    steps = 0

    while f_iters < max_f_iters and steps < n_steps:
        if steps >= n_steps:
            break

        pivot_idx = random.randint(1, L-1)
        new_saw = apply_pivot(current_saw, pivot_idx)

        if new_saw:
            rg_old = Rg(current_saw)
            rg_new = Rg(new_saw)
            b_old = get_rg_bin(rg_old, rg_bins)
            b_new = get_rg_bin(rg_new, rg_bins)

            log_w_old = log_weights[b_old]
            log_w_new = log_weights[b_new]

            accept_prob = min(1.0, np.exp(max(-700, min((log_w_old - log_w_new)*20, 700)))) 
            if random.random() < accept_prob:
                current_saw = new_saw
                b_old = b_new

            log_weights[b_old] += np.log(f)
            visits[b_old] += 1
            hist[b_old] += 1
        steps += 1
            

        # Check histogram flatness and reduce f
        if steps % flat_check_interval == 0:
            if is_flat(hist):
                print(f"Histogram flat at step {steps}, reducing f → sqrt(f) {mse_hist(hist)}")
                
                f = np.sqrt(f)
                hist = defaultdict(int)
                f_iters += 1

        if steps % int(reset_interval *1/f) == 0:
            current_saw = [(i, 0) for i in range(L+1)]

    # Normalize DOS
    max_log_w = max(log_weights.values())
    dos_estimates = {b: np.exp(log_weights[b] - max_log_w) for b in log_weights}
    c_L = sum(dos_estimates.values())
    return c_L, visits, rg_bins

def plot_histogram(histogram, rg_bins, title="Histogram of Rg bins"):
    bins = np.arange(len(rg_bins)+1)
    counts = [histogram.get(b, 0) for b in bins]
    plt.figure(figsize=(8, 4))
    plt.bar(bins, counts, width=0.9, align='center')
    plt.xlabel("Rg bin index")
    plt.ylabel("Count")
    plt.title(title)
    plt.grid(True)
    plt.show()

def main():
    for L in range(100, 300, 50):
        c_L, histogram, rg_bins = multicanonical_wl(L)
        c_L1, histogram, rg_bins = multicanonical_wl(L)
        print(f"Estimated number of SAWs (c_{L}): {c_L:.2e} Estimated number of SAWs (c_{L+1}): {c_L1:.2e} mu: {c_L1/c_L}")
        plot_histogram(histogram, rg_bins)
    

if __name__ == "__main__":
    main()
# Out:
# Histogram flat at step 60000, reducing f → sqrt(f) 1431.4727153188694
# Histogram flat at step 80000, reducing f → sqrt(f) 1438.5263157894738
# Estimated number of SAWs (c_100): 5.44e+00 Estimated number of SAWs (c_101): 2.11e+00 mu: 0.388602517587027
# Histogram flat at step 80000, reducing f → sqrt(f) 7307.920360110805
# Histogram flat at step 60000, reducing f → sqrt(f) 3598.1198060941824
# Estimated number of SAWs (c_150): 5.03e+00 Estimated number of SAWs (c_151): 1.56e+00 mu: 0.31017805318265373
# Estimated number of SAWs (c_200): 1.78e+00 Estimated number of SAWs (c_201): 1.20e+00 mu: 0.6741182622015442
# Estimated number of SAWs (c_250): 1.25e+00 Estimated number of SAWs (c_251): 2.80e+00 mu: 2.2299639765680177
